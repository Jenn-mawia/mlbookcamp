# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenn-mawia/mlbookcamp/blob/main/Introduction_to_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Dataframes

# %%
# create dataframe from a list of lists
data = [
    ['Nissan', 'Stanza', 1991, 138, 4, 'MANUAL', 'sedan', 2000],
    ['Hyundai', 'Sonata', 2017, None, 4, 'AUTOMATIC', 'Sedan', 27150],
    ['Lotus', 'Elise', 2010, 218, 4, 'MANUAL', 'convertible', 54990],
    ['GMC', 'Acadia',  2017, 194, 4, 'AUTOMATIC', '4dr SUV', 34450],
    ['Nissan', 'Frontier', 2017, 261, 6, 'MANUAL', 'Pickup', 32340],
]

columns = [
    'Make', 'Model', 'Year', 'Engine HP', 'Engine Cylinders',
    'Transmission Type', 'Vehicle_Style', 'MSRP'
]

# %%
df = pd.DataFrame(data, columns=columns)
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
# create dataframe from a list of dictionaries
data = [
    {
        "Make": "Nissan",
        "Model": "Stanza",
        "Year": 1991,
        "Engine HP": 138.0,
        "Engine Cylinders": 4,
        "Transmission Type": "MANUAL",
        "Vehicle_Style": "sedan",
        "MSRP": 2000
    },
    {
        "Make": "Hyundai",
        "Model": "Sonata",
        "Year": 2017,
        "Engine HP": None,
        "Engine Cylinders": 4,
        "Transmission Type": "AUTOMATIC",
        "Vehicle_Style": "Sedan",
        "MSRP": 27150
    },
    {
        "Make": "Lotus",
        "Model": "Elise",
        "Year": 2010,
        "Engine HP": 218.0,
        "Engine Cylinders": 4,
        "Transmission Type": "MANUAL",
        "Vehicle_Style": "convertible",
        "MSRP": 54990
    },
    {
        "Make": "GMC",
        "Model": "Acadia",
        "Year": 2017,
        "Engine HP": 194.0,
        "Engine Cylinders": 4,
        "Transmission Type": "AUTOMATIC",
        "Vehicle_Style": "4dr SUV",
        "MSRP": 34450
    },
    {
        "Make": "Nissan",
        "Model": "Frontier",
        "Year": 2017,
        "Engine HP": 261.0,
        "Engine Cylinders": 6,
        "Transmission Type": "MANUAL",
        "Vehicle_Style": "Pickup",
        "MSRP": 32340
    }
]

# %%
df = pd.DataFrame(data)
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
df.head(n=2)
# Out:
#       Make   Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan  Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai  Sonata  2017        NaN                 4         AUTOMATIC
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150

# %% [markdown]
# # Series
#
# Every column in a pandas dataframe is a series

# %%
print(df.Make)
df['Make']
# Out:
# 0     Nissan
# 1    Hyundai
# 2      Lotus
# 3        GMC
# 4     Nissan
# Name: Make, dtype: object
# 0     Nissan
# 1    Hyundai
# 2      Lotus
# 3        GMC
# 4     Nissan
# Name: Make, dtype: object

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine HP', 'Engine Cylinders',
#        'Transmission Type', 'Vehicle_Style', 'MSRP'],
#       dtype='object')

# %%
df['Engine HP']
# Out:
# 0    138.0
# 1      NaN
# 2    218.0
# 3    194.0
# 4    261.0
# Name: Engine HP, dtype: float64

# %%
# Access multiple columns
df[['Make', 'Model', 'MSRP']]
# Out:
#       Make     Model   MSRP
# 0   Nissan    Stanza   2000
# 1  Hyundai    Sonata  27150
# 2    Lotus     Elise  54990
# 3      GMC    Acadia  34450
# 4   Nissan  Frontier  32340

# %%
# Add a column
df['id'] = [1,2,3,4,5]
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP  id
# 0         sedan   2000   1
# 1         Sedan  27150   2
# 2   convertible  54990   3
# 3       4dr SUV  34450   4
# 4        Pickup  32340   5

# %%
# change id to different values
df['id'] = [10,20,30,40,50]
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP  id
# 0         sedan   2000  10
# 1         Sedan  27150  20
# 2   convertible  54990  30
# 3       4dr SUV  34450  40
# 4        Pickup  32340  50

# %%
# remove column 
del df['id']
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %% [markdown]
# # Index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.Make.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# access elements of the df using indices
df.loc[1] #returns row 1
# Out:
# Make                   Hyundai
# Model                   Sonata
# Year                      2017
# Engine HP                  NaN
# Engine Cylinders             4
# Transmission Type    AUTOMATIC
# Vehicle_Style            Sedan
# MSRP                     27150
# Name: 1, dtype: object

# %%
# access multiple rows
df.loc[[1,2]]
# Out:
#       Make   Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 1  Hyundai  Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus   Elise  2010      218.0                 4            MANUAL
#
#   Vehicle_Style   MSRP
# 1         Sedan  27150
# 2   convertible  54990

# %%
# change index values
df.index = ['a','b','c','d','e']
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# a   Nissan    Stanza  1991      138.0                 4            MANUAL
# b  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# c    Lotus     Elise  2010      218.0                 4            MANUAL
# d      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# e   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# a         sedan   2000
# b         Sedan  27150
# c   convertible  54990
# d       4dr SUV  34450
# e        Pickup  32340

# %%
df.loc[['b', 'c']]
# Out:
#       Make   Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# b  Hyundai  Sonata  2017        NaN                 4         AUTOMATIC
# c    Lotus   Elise  2010      218.0                 4            MANUAL
#
#   Vehicle_Style   MSRP
# b         Sedan  27150
# c   convertible  54990

# %%
df.loc[[1,2]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-3148caf71ea1> in <cell line: 1>()
# ----> 1 df.loc[[1,2]]
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1299                     raise ValueError("Cannot index with multidimensional key")
#    1300
# -> 1301                 return self._getitem_iterable(key, axis=axis)
#    1302
#    1303             # nested tuple slicing
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1237
# ...

# %%
# access using the positional index
df.iloc[[1,2,3]]
# Out:
#       Make   Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# b  Hyundai  Sonata  2017        NaN                 4         AUTOMATIC
# c    Lotus   Elise  2010      218.0                 4            MANUAL
# d      GMC  Acadia  2017      194.0                 4         AUTOMATIC
#
#   Vehicle_Style   MSRP
# b         Sedan  27150
# c   convertible  54990
# d       4dr SUV  34450

# %%
# return to original index
df = df.reset_index(drop=True)
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %% [markdown]
# # Element-wise operations
#
# process is similar to numpy

# %%
# Division
print(df['Engine HP']/100)

# Multiplication
print(df['Engine HP']*2)
# Out:
# 0    1.38
# 1     NaN
# 2    2.18
# 3    1.94
# 4    2.61
# Name: Engine HP, dtype: float64
# 0    276.0
# 1      NaN
# 2    436.0
# 3    388.0
# 4    522.0
# Name: Engine HP, dtype: float64

# %%
df['Year']>=2015
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# Name: Year, dtype: bool

# %% [markdown]
# # Filtering

# %%
# all cars manufactured after 2015
df[df['Year']>=2015]
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 1         Sedan  27150
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
df[df['Make']=='Nissan']
# Out:
#      Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0  Nissan    Stanza  1991      138.0                 4            MANUAL
# 4  Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 4        Pickup  32340

# %%
df[
    (df['Make']=='Nissan') & (df['Year']>=2015)
    ]
# Out:
#      Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 4  Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 4        Pickup  32340

# %% [markdown]
# # String Operations

# %%
df['Vehicle_Style']
# Out:
# 0          sedan
# 1          Sedan
# 2    convertible
# 3        4dr SUV
# 4         Pickup
# Name: Vehicle_Style, dtype: object

# %%
# make every element of the series lowercase
df['Vehicle_Style'].str.lower()
# Out:
# 0          sedan
# 1          sedan
# 2    convertible
# 3        4dr suv
# 4         pickup
# Name: Vehicle_Style, dtype: object

# %%
'machine learning zoomcamp'.replace(' ', '_')
# Out:
# 'machine_learning_zoomcamp'

# %%
df['Vehicle_Style'].str.replace(' ', '_').str.lower()
# Out:
# 0          sedan
# 1          sedan
# 2    convertible
# 3        4dr_suv
# 4         pickup
# Name: Vehicle_Style, dtype: object

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
df['Vehicle_Style'] = df['Vehicle_Style'].str.replace(' ', '_').str.lower()
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         sedan  27150
# 2   convertible  54990
# 3       4dr_suv  34450
# 4        pickup  32340

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')
df
# Out:
#       make     model  year  engine_hp  engine_cylinders transmission_type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   vehicle_style   msrp
# 0         sedan   2000
# 1         sedan  27150
# 2   convertible  54990
# 3       4dr_suv  34450
# 4        pickup  32340

# %%
df.dtypes == 'object'
# Out:
# make                  True
# model                 True
# year                 False
# engine_hp            False
# engine_cylinders     False
# transmission_type     True
# vehicle_style         True
# msrp                 False
# dtype: bool

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# make                 object
# model                object
# transmission_type    object
# vehicle_style        object
# dtype: object

# %%
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['make', 'model', 'transmission_type', 'vehicle_style'], dtype='object')

# %%
list(df.dtypes[df.dtypes == 'object'].index)
# Out:
# ['make', 'model', 'transmission_type', 'vehicle_style']

# %%
df
# Out:
#       make     model  year  engine_hp  engine_cylinders transmission_type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   vehicle_style   msrp
# 0         sedan   2000
# 1         sedan  27150
# 2   convertible  54990
# 3       4dr_suv  34450
# 4        pickup  32340

# %%
string_columns = df.dtypes[df.dtypes == 'object'].index

for col in string_columns:
    df[col] = df[col].str.lower().str.replace(' ', '_')

df
# Out:
#       make     model  year  engine_hp  engine_cylinders transmission_type  \
# 0   nissan    stanza  1991      138.0                 4            manual
# 1  hyundai    sonata  2017        NaN                 4         automatic
# 2    lotus     elise  2010      218.0                 4            manual
# 3      gmc    acadia  2017      194.0                 4         automatic
# 4   nissan  frontier  2017      261.0                 6            manual
#
#   vehicle_style   msrp
# 0         sedan   2000
# 1         sedan  27150
# 2   convertible  54990
# 3       4dr_suv  34450
# 4        pickup  32340

# %% [markdown]
# # Summarizing operations

# %%
df.msrp.mean()
# Out:
# 30186.0

# %%
df.msrp.describe()
# Out:
# count        5.000000
# mean     30186.000000
# std      18985.044904
# min       2000.000000
# 25%      27150.000000
# 50%      32340.000000
# 75%      34450.000000
# max      54990.000000
# Name: msrp, dtype: float64

# %%
df.describe().round(2) #only for numerical columns
# Out:
#           year  engine_hp  engine_cylinders      msrp
# count     5.00       4.00              5.00      5.00
# mean   2010.40     202.75              4.40  30186.00
# std      11.26      51.30              0.89  18985.04
# min    1991.00     138.00              4.00   2000.00
# 25%    2010.00     180.00              4.00  27150.00
# 50%    2017.00     206.00              4.00  32340.00
# 75%    2017.00     228.75              4.00  34450.00
# max    2017.00     261.00              6.00  54990.00

# %%
df.make.nunique() #count unique values in Make column
# Out:
# 4

# %%
df.nunique()
# Out:
# make                 4
# model                5
# year                 3
# engine_hp            4
# engine_cylinders     2
# transmission_type    2
# vehicle_style        4
# msrp                 5
# dtype: int64

# %% [markdown]
# # Missing Values

# %%
df.isnull().sum()
# Out:
# make                 0
# model                0
# year                 0
# engine_hp            1
# engine_cylinders     0
# transmission_type    0
# vehicle_style        0
# msrp                 0
# dtype: int64

# %%
df.engine_hp.fillna(0)
# Out:
# 0    138.0
# 1      0.0
# 2    218.0
# 3    194.0
# 4    261.0
# Name: engine_hp, dtype: float64

# %%
df.engine_hp.fillna(df.engine_hp.mean())
# Out:
# 0    138.00
# 1    202.75
# 2    218.00
# 3    194.00
# 4    261.00
# Name: engine_hp, dtype: float64

# %%
df.engine_hp = df.engine_hp.fillna(df.engine_hp.mean())
df
# Out:
#       make     model  year  engine_hp  engine_cylinders transmission_type  \
# 0   nissan    stanza  1991     138.00                 4            manual
# 1  hyundai    sonata  2017     202.75                 4         automatic
# 2    lotus     elise  2010     218.00                 4            manual
# 3      gmc    acadia  2017     194.00                 4         automatic
# 4   nissan  frontier  2017     261.00                 6            manual
#
#   vehicle_style   msrp
# 0         sedan   2000
# 1         sedan  27150
# 2   convertible  54990
# 3       4dr_suv  34450
# 4        pickup  32340

# %% [markdown]
# # Sorting and re-ordering

# %%
df.sort_values(by='msrp')
# Out:
#       make     model  year  engine_hp  engine_cylinders transmission_type  \
# 0   nissan    stanza  1991     138.00                 4            manual
# 1  hyundai    sonata  2017     202.75                 4         automatic
# 4   nissan  frontier  2017     261.00                 6            manual
# 3      gmc    acadia  2017     194.00                 4         automatic
# 2    lotus     elise  2010     218.00                 4            manual
#
#   vehicle_style   msrp
# 0         sedan   2000
# 1         sedan  27150
# 4        pickup  32340
# 3       4dr_suv  34450
# 2   convertible  54990

# %%
df.sort_values(by='msrp', ascending=False)
# Out:
#       make     model  year  engine_hp  engine_cylinders transmission_type  \
# 2    lotus     elise  2010     218.00                 4            manual
# 3      gmc    acadia  2017     194.00                 4         automatic
# 4   nissan  frontier  2017     261.00                 6            manual
# 1  hyundai    sonata  2017     202.75                 4         automatic
# 0   nissan    stanza  1991     138.00                 4            manual
#
#   vehicle_style   msrp
# 2   convertible  54990
# 3       4dr_suv  34450
# 4        pickup  32340
# 1         sedan  27150
# 0         sedan   2000

# %% [markdown]
# # Grouping

# %% [markdown]
# ```
# SELECT
#     transmission_type,
#     AVG(MSRP)
# FROM
#     cars
# GROUP BY
#     transmission_type
# ```

# %%
df.groupby('Transmission Type').MSRP.mean()
# Out:
# Transmission Type
# AUTOMATIC    30800.000000
# MANUAL       29776.666667
# Name: MSRP, dtype: float64

# %% [markdown]
# ```
# SELECT
#     transmission_type,
#     AVG(msrp),
#     COUNT(msrp
# FROM
#     cars
# GROUP BY
#     transmission_type
# ```

# %%
df.groupby('transmission_type').msrp.agg(['mean', 'count'])
# Out:
#                            mean  count
# transmission_type
# automatic          30800.000000      2
# manual             29776.666667      3

# %%
df_group = df.groupby('transmission_type').msrp.agg(['mean', 'count'])
df_group
# Out:
#                            mean  count
# transmission_type
# automatic          30800.000000      2
# manual             29776.666667      3

# %%
df_group['mean'] - df.msrp.mean()
# Out:
# transmission_type
# automatic    614.000000
# manual      -409.333333
# Name: mean, dtype: float64

# %% [markdown]
# # Getting the NumPy arrays

# %%
df.MSRP
# Out:
# 0     2000
# 1    27150
# 2    54990
# 3    34450
# 4    32340
# Name: MSRP, dtype: int64

# %%
df.MSRP.values #the actual numpy array used
# Out:
# array([ 2000, 27150, 54990, 34450, 32340])

# %% [markdown]
# # Convert to dictionary

# %%
df.to_dict(orient='records') # convert pandas df back to a list with dictionaries
# Out:
# [{'Make': 'Nissan',
#   'Model': 'Stanza',
#   'Year': 1991,
#   'Engine HP': 138.0,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'MANUAL',
#   'Vehicle_Style': 'sedan',
#   'MSRP': 2000},
#  {'Make': 'Hyundai',
#   'Model': 'Sonata',
#   'Year': 2017,
#   'Engine HP': nan,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'AUTOMATIC',
#   'Vehicle_Style': 'sedan',
#   'MSRP': 27150},
#  {'Make': 'Lotus',
#   'Model': 'Elise',
#   'Year': 2010,
#   'Engine HP': 218.0,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'MANUAL',
#   'Vehicle_Style': 'convertible',
#   'MSRP': 54990},
#  {'Make': 'GMC',
#   'Model': 'Acadia',
#   'Year': 2017,
#   'Engine HP': 194.0,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'AUTOMATIC',
#   'Vehicle_Style': '4dr_suv',
#   'MSRP': 34450},
#  {'Make': 'Nissan',
#   'Model': 'Frontier',
#   'Year': 2017,
#   'Engine HP': 261.0,
#   'Engine Cylinders': 6,
#   'Transmission Type': 'MANUAL',
#   'Vehicle_Style': 'pickup',
# ...
